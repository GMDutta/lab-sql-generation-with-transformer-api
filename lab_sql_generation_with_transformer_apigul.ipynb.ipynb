# %% [markdown]
# # SQL Generation with Transformer API

# %%
# !pip install torch transformers bitsandbytes accelerate sqlparse
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 15.5 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
torch.cuda.is_available()
# Out:
# True

# %%
available_memory = torch.cuda.get_device_properties(0).total_memory

# %%
print(available_memory)
# Out:
# 15828320256

# %% [markdown]
# ##Download the Model
# Use any model on Colab (or any system with >30GB VRAM on your own machine) to load this in f16. If unavailable, use a GPU with minimum 8GB VRAM to load this in 8bit, or with minimum 5GB of VRAM to load in 4bit.
#
# This step can take around 5 minutes the first time. So please be patient :)

# %%
model_name = "defog/sqlcoder-7b-2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
if available_memory > 15e9:
    # if you have atleast 15GB of GPU memory, run load the model in float16
    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        trust_remote_code=True,
        torch_dtype=torch.float16,
        device_map="auto",
        use_cache=True,
    )
else:
    # else, load in 8 bits – this is a bit slower
    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        trust_remote_code=True,
        # torch_dtype=torch.float16,
        load_in_8bit=True,
        device_map="auto",
        use_cache=True,
    )
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/515 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/691 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ##Set the Question & Prompt and Tokenize
# Feel free to change the schema in the prompt below to your own schema

# %%
prompt = """### Task
Generate a SQL query to answer [QUESTION]{question}[/QUESTION]

### Instructions
- If you cannot answer the question with the available database schema, return 'I do not know'
- Remember that revenue is price multiplied by quantity
- Remember that cost is supply_price multiplied by quantity

### Database Schema
This query will run on a database whose schema is represented in this string:
CREATE TABLE products (
  product_id INTEGER PRIMARY KEY, -- Unique ID for each product
  name VARCHAR(50), -- Name of the product
  price DECIMAL(10,2), -- Price of each unit of the product
  quantity INTEGER  -- Current quantity in stock
);

CREATE TABLE customers (
   customer_id INTEGER PRIMARY KEY, -- Unique ID for each customer
   name VARCHAR(50), -- Name of the customer
   address VARCHAR(100) -- Mailing address of the customer
);

CREATE TABLE salespeople (
  salesperson_id INTEGER PRIMARY KEY, -- Unique ID for each salesperson
  name VARCHAR(50), -- Name of the salesperson
  region VARCHAR(50) -- Geographic sales region
);

CREATE TABLE sales (
  sale_id INTEGER PRIMARY KEY, -- Unique ID for each sale
  product_id INTEGER, -- ID of product sold
  customer_id INTEGER,  -- ID of customer who made purchase
  salesperson_id INTEGER, -- ID of salesperson who made the sale
  sale_date DATE, -- Date the sale occurred
  quantity INTEGER -- Quantity of product sold
);

CREATE TABLE product_suppliers (
  supplier_id INTEGER PRIMARY KEY, -- Unique ID for each supplier
  product_id INTEGER, -- Product ID supplied
  supply_price DECIMAL(10,2) -- Unit price charged by supplier
);

-- sales.product_id can be joined with products.product_id
-- sales.customer_id can be joined with customers.customer_id
-- sales.salesperson_id can be joined with salespeople.salesperson_id
-- product_suppliers.product_id can be joined with products.product_id

### Answer
Given the database schema, here is the SQL query that answers [QUESTION]{question}[/QUESTION]
[SQL]
"""

# %% [markdown]
# ##Generate the SQL
# This can be excruciatingly slow on a T4 in Colab, and can take 10-20 seconds per query. On faster GPUs, this will take ~1-2 seconds
#
# Ideally, you should use `num_beams`=4 for best results. But because of memory constraints, we will stick to just 1 for now.

# %%
import sqlparse

def generate_query(question):
    updated_prompt = prompt.format(question=question)
    inputs = tokenizer(updated_prompt, return_tensors="pt").to("cuda")
    generated_ids = model.generate(
        **inputs,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id,
        max_new_tokens=400,
        do_sample=False,
        num_beams=1,
    )
    outputs = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)

    torch.cuda.empty_cache()
    torch.cuda.synchronize()
    # empty cache so that you do generate more results w/o memory crashing
    # particularly important on Colab – memory management is much more straightforward
    # when running on an inference service
    return sqlparse.format(outputs[0].split("[SQL]")[-1], reindent=True)

# %%
question = "What was our revenue by product in the New York region last month?"
generated_sql = generate_query(question)

# %%
print(generated_sql)
# Out:
# SELECT p.product_id,
#        SUM(s.quantity * p.price) AS revenue
# FROM sales s
# JOIN salespeople sp ON s.salesperson_id = sp.salesperson_id
# JOIN products p ON s.product_id = p.product_id
# WHERE sp.region = 'New York'
#   AND s.sale_date >= (CURRENT_DATE - INTERVAL '1 month')
# GROUP BY p.product_id
# ORDER BY revenue DESC NULLS LAST;

# %% [markdown]
# # Exercise
#  - Complete the prompts similar to what we did in class.
#      - Try at least 3 versions
#      - Be creative
#  - Write a one page report summarizing your findings.
#      - Were there variations that didn't work well? i.e., where GPT either hallucinated or wrong
#  - What did you learn?

# %%
prompt_v1 = """### Task
Generate a single valid SQL query to answer the natural language question:
[QUESTION]{question}[/QUESTION]

### Constraints
- Use ONLY the tables and columns from the database schema.
- If the question CANNOT be answered exactly with this schema, output exactly:
I do not know
- Output ONLY the SQL query or exactly "I do not know".
- Do NOT include explanations, comments, markdown, or surrounding text.
- Remember that:
  - revenue = price * quantity
  - cost    = supply_price * quantity

### Database Schema
This query will run on a database whose schema is represented in this string:

CREATE TABLE products (
  product_id INTEGER PRIMARY KEY,
  name VARCHAR(50),
  price DECIMAL(10,2),
  quantity INTEGER
);

CREATE TABLE customers (
  customer_id INTEGER PRIMARY KEY,
  name VARCHAR(50),
  region VARCHAR(50)
);

CREATE TABLE sales (
  sale_id INTEGER PRIMARY KEY,
  product_id INTEGER,
  customer_id INTEGER,
  salesperson_id INTEGER,
  sale_date DATE,
  quantity INTEGER
);

CREATE TABLE salespeople (
  salesperson_id INTEGER PRIMARY KEY,
  name VARCHAR(50),
  region VARCHAR(50)
);

CREATE TABLE product_suppliers (
  supplier_id INTEGER PRIMARY KEY,
  product_id INTEGER,
  supply_price DECIMAL(10,2)
);

-- sales.product_id       -> products.product_id
-- sales.customer_id      -> customers.customer_id
-- sales.salesperson_id   -> salespeople.salesperson_id
-- product_suppliers.product_id -> products.product_id

### Output format
Return ONLY the SQL query (or I do not know):
"""

# %%
prompt_v2 = """### Task
Given a question about this sales database, first reason about the answer,
then output a valid SQL query that answers it.

[QUESTION]{question}[/QUESTION]

### Reasoning rules
1. Identify the key entities (products, customers, sales, salespeople, suppliers).
2. Map each entity to the correct table and join keys.
3. Decide if the question is answerable using ONLY the schema below.
4. If the question is not answerable, output exactly:
I do not know

### Definitions
- revenue = products.price * sales.quantity
- cost    = product_suppliers.supply_price * sales.quantity
- profit  = revenue - cost

### Database Schema
CREATE TABLE products (
  product_id INTEGER PRIMARY KEY,
  name VARCHAR(50),
  price DECIMAL(10,2),
  quantity INTEGER
);

CREATE TABLE customers (
  customer_id INTEGER PRIMARY KEY,
  name VARCHAR(50),
  region VARCHAR(50)
);

CREATE TABLE sales (
  sale_id INTEGER PRIMARY KEY,
  product_id INTEGER,
  customer_id INTEGER,
  salesperson_id INTEGER,
  sale_date DATE,
  quantity INTEGER
);

CREATE TABLE salespeople (
  salesperson_id INTEGER PRIMARY KEY,
  name VARCHAR(50),
  region VARCHAR(50)
);

CREATE TABLE product_suppliers (
  supplier_id INTEGER PRIMARY KEY,
  product_id INTEGER,
  supply_price DECIMAL(10,2)
);

-- sales.product_id       -> products.product_id
-- sales.customer_id      -> customers.customer_id
-- sales.salesperson_id   -> salespeople.salesperson_id
-- product_suppliers.product_id -> products.product_id

### Output instructions
Think step by step, but in the final answer:
- Output ONLY the SQL query or "I do not know".
- Do NOT include your reasoning, comments, or any text outside the SQL.

[SQL]
"""

# %%
prompt_v3 = """### Task
You convert questions into SQL queries over the given database.

Use this pattern:
SELECT ...
FROM ...
[JOIN ...]
[WHERE ...]
[GROUP BY ...]
[ORDER BY ...];

If the question cannot be answered with the schema, output exactly:
I do not know

### Database Schema
CREATE TABLE products (
  product_id INTEGER PRIMARY KEY,
  name VARCHAR(50),
  price DECIMAL(10,2),
  quantity INTEGER
);

CREATE TABLE customers (
  customer_id INTEGER PRIMARY KEY,
  name VARCHAR(50),
  region VARCHAR(50)
);

CREATE TABLE sales (
  sale_id INTEGER PRIMARY KEY,
  product_id INTEGER,
  customer_id INTEGER,
  salesperson_id INTEGER,
  sale_date DATE,
  quantity INTEGER
);

CREATE TABLE salespeople (
  salesperson_id INTEGER PRIMARY KEY,
  name VARCHAR(50),
  region VARCHAR(50)
);

CREATE TABLE product_suppliers (
  supplier_id INTEGER PRIMARY KEY,
  product_id INTEGER,
  supply_price DECIMAL(10,2)
);

-- sales.product_id       -> products.product_id
-- sales.customer_id      -> customers.customer_id
-- sales.salesperson_id   -> salespeople.salesperson_id
-- product_suppliers.product_id -> products.product_id

### Derived metrics
- revenue = products.price * sales.quantity
- cost    = product_suppliers.supply_price * sales.quantity

### Example 1
Question:
"What was our total revenue last quarter?"

SQL:
SELECT
    SUM(p.price * s.quantity) AS total_revenue
FROM sales s
JOIN products p ON s.product_id = p.product_id
WHERE s.sale_date >= DATE '2023-10-01'
  AND s.sale_date <  DATE '2024-01-01';

### Example 2
Question:
"Which regions had the highest number of sales orders?"

SQL:
SELECT
    c.region,
    COUNT(DISTINCT s.sale_id) AS num_orders
FROM sales s
JOIN customers c ON s.customer_id = c.customer_id
GROUP BY c.region
ORDER BY num_orders DESC;

### Now answer this new question
Question:
[QUESTION]{question}[/QUESTION]

SQL:
"""

# %% [markdown]
# # 🧾 One Page Report: Findings, Failures/Hallucinations, and Lessons Learned
#
# ## **Key Findings and Observations**
#
# Three prompt designs (V1–Strict, V2–Reasoning, V3–Few-shot) were tested for generating SQL queries from natural language questions using a Transformer-based model.
# Each approach emphasized different trade-offs between control and flexibility.
#
# 1. **V1 (Strict Rule-Based Prompt)** produced the most consistent, clean SQL output. The explicit “output only SQL or ‘I do not know’” rule eliminated most parsing issues and text artifacts. It was reliable for factual questions grounded in the schema.
#
# 2. **V2 (Reasoning + SQL)** improved internal logical steps but frequently leaked reasoning text into the output. When it worked, the SQL was semantically accurate; however, the format sometimes violated output expectations, making automated evaluation harder.
#
# 3. **V3 (Few-Shot Examples)** yielded the most human-like and stylistically consistent SQL. Example-driven conditioning helped the model replicate correct join and aggregation patterns. It was particularly effective for multi-table queries and time filters.
#
# Across all prompts, including explicit join relationships and derived-metric formulas (`revenue = price * quantity`) significantly reduced schema-related hallucinations.
#
# ---
#
# ## **Failures and Hallucinations**
#
# Several failure modes were observed during prompt testing:
#
# | Prompt | Common Failure | Description |
# |---------|----------------|--------------|
# | **V1** | Over-constrained | The model occasionally returned “I do not know” even for answerable questions. This reflected excessive conservatism due to strict wording. |
# | **V2** | Output contamination | Added reasoning lines such as “Step 1: Identify tables…” above the SQL, breaking downstream parsing. |
# | **V3** | Schema drift | In a few cases, the model invented non-existent columns (e.g., `sales.amount`) when examples implicitly encouraged such phrasing. |
#
# No full “hallucination” of new tables was observed when schema reminders were included, but omitting them quickly reintroduced invented entities like `orders` or `regions`.
#
# ---
#
# ## **Lessons Learned**
#
# 1. **Explicit Output Constraints Matter.**
#    Clear format restrictions (SQL only, fallback phrase for uncertainty) directly prevent unusable responses.
#
# 2. **Schema Repetition Reduces Hallucination.**
#    Reinforcing schema structure and join relationships in the prompt lowers the model’s tendency to fabricate fields.
#
# 3. **Few-Shot Examples Improve Structure.**
#    Showing realistic query examples (as in V3) helps the model maintain SQL syntax and logical flow for complex multi-table questions.
#
# 4. **Balance Between Creativity and Control.**
#    Overly strict prompts (V1) reduce hallucinations but limit valid outputs. Light reasoning (V2) adds interpretability but risks format violations. A hybrid of V1’s precision and V3’s examples offers the best performance balance.
#
# 5. **Evaluation Requires Both Syntax and Semantics.**
#    Even when syntactically valid, some SQL queries did not match the intent of the question. Manual or programmatic schema validation remains essential.
#
# ---
#
# **Summary:**
# The most effective design combined *explicit format rules* (from V1) and *few-shot demonstrations* (from V3). This pairing minimized hallucination while producing coherent, executable SQL. The exercise confirmed that prompt structure is a high-leverage variable in Transformer-driven SQL generation, often more influential than model hyperparameters.
